# %%
import pandas as pd

fake = pd.read_csv("dataset/Fake.csv")
true = pd.read_csv("dataset/True.csv")

print(fake.head())
print(true.head())

print(fake.shape)
print(true.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2
#       3 fake = pd.read_csv("dataset/Fake.csv")
#       4 true = pd.read_csv("dataset/True.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Taashu\Desktop\news-varifier-newsverifier\.venv\Scripts\python.exe
